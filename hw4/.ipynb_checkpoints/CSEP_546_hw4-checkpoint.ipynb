# %% [markdown]
# **1a:** True, in optimizing for
#
# ![image.png](data:image/png;base64,...)
#
# , PCA will create basis vectors that map perfectly to the rank of X

# %% [markdown]
# **1b:** False, there are cases where S has smaller dimensions than X. (S is rxr where r < n)
#
# **1c:** False, Choosing k is a good way to minimize the k-means objective since we would get different clusters given different ks. However, if we are optimizing for k, the k can match the number of datapoints since this would result in the lowest distance between k and data-points. It's better to optimize for a different higher-level objective.
#
# **1d:** True, In [U,S,V] = svd(A), the s contains the singular values of M. The number of non-zero singular values are equal to the rank of A. Therefore s is unique.
#
# **1e:** True, the definition of the
# rank of a matrix can be defined as being the number of non-zero eigenvalues of the matrix that are not repeated.

# %% [markdown]
# **2a:**
#
# (1) any pre-processing steps you would take (i.e., data acquisition and processing)
#
#     Since new users will not fully enter in their personal data, I will pre-process features from the input pipeline to match the set of features that new users would enter that can not be inferred.
#
# (2) the specific machine learning pipeline you would use (i.e., algorithms and techniques learned in this class)
#
#
#     From a model training prespective, post-processing pipelines will take the demographic data and infer features like location from their point of entry. Methods like k-means clustering can be used to engineer features to align with those closest to the model. Missing features would be normalized when training the model. Sampling should be used to simulate the limited input situations by imputing data points with the mean in order to reduce the weight of possible limited input features. From a modeling prespective, Logistic Regression can be used to model the susceptibiity via olds ratios.
#
# (3) how your setup acknowledges the constraints and achieves the desired result.
#
#        Given the input processing steps, the model will not overfit on the full set of rich features. This allows us to have good test accuracy and real-world performance.

# %% [markdown]
# **2b:**
#
# (1) any pre-processing steps you would take (i.e., data acquisition and processing)
#
#     Existing faces will be converted into numpy arrays via ingestion pipelines. Additionally, just the dataset from the company might not be enough. Pipelines connecting to open source images that are similar to the employees can be used to supplement the filter.
#
# (2) the specific machine learning pipeline you would use (i.e., algorithms and techniques learned in this class)
#
#     While PCA can be used to create eigenvectors that describle the face inputted quickly, a neural network architecture should be used to accurately identify prominant features for filter applications.
#
# (3) how your setup acknowledges the constraints and achieves the desired result.
#
#     With the implementation of a neural network, filters can easily be applied.

# %% [markdown]
# **2c:**
#
#     This can result in negative feedback loops where police will spend more time patrolling areas where crime is reported quickly. Because of the reduction in police resources, minority communities may not have adequate police protection.
#
# **2d:**
#
#     Given my k-means clustering method, some demographics might have larger clusters resulting in more accurate feature engineering. To deal with this issue, I can bootstrap data-counts for smaller demographics to create more balanced input sets.

# %% [markdown]
# **3b:**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **3c:**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **4a:**
#
#  λ1: 4.812204
#
#  λ2: 3.741114
#
#  λ10: 1.115113
#
#  λ30: 0.361828
#
#  λ50: 0.168786
#
#  sum of λ_i = 74.425448

# %% [markdown]
# **4b:**
#
# If we let x = A, we can decompose A via singular value decomposition as shown below:
# ![image.png](attachment:image.png)
#
# Given that A is n x d dimensions-wise, U would be n x n, S would be n x d, and V.T would be d x d
#
# If we reduce the rank to k, then A_k will be describled by the below formula:
# ![image-2.png](attachment:image-2.png)
#
# A_k would still be n x d. However, S_k in this case would be reduced to k x k with from S
#
# Using S_k, we can create an PCA reconstruction with the mean vector of the original data x, V_k and the PC scores S_k

# %% [markdown]
# **4c:**
#
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **4d:**
#
# The first few PCs are clear and create strong projections and clearly defined features for the different digits. The first few PCs also capture the greatest variance. As we look at further pcs, they contribute less and less to the overall digit.
#
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# **4e:**
# k = 5
# ![image.png](attachment:image.png)
#
# k = 15
# ![image-2.png](attachment:image-2.png)
#
# k = 40
# ![image-3.png](attachment:image-3.png)
#
# k = 100
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# **7:** 35 hours total
